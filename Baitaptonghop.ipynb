# %% [markdown]
# <a href="https://colab.research.google.com/github/huynhhaioke20/THToanCaoCap/blob/main/Baitaptonghop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
n = 10
dayS = [1/2**k for k in range(0, n)]

# %%
dayS
# Out:
# [1.0,
#  0.5,
#  0.25,
#  0.125,
#  0.0625,
#  0.03125,
#  0.015625,
#  0.0078125,
#  0.00390625,
#  0.001953125]

# %%
len(dayS)
# Out:
# 10

# %%
sum(dayS)
# Out:
# 1.998046875

# %% [markdown]
# Bài 2

# %%
n = 1000
x = [(2-0)*k/n for k in range(0, n+1)]
s = 0
for k in range(1, n+1):
  s = s + x[k]**2*(x[k] - x[k-1])
  print(s)
# Out:
# 8e-09
# 4e-08
# 1.1200000000000001e-07
# 2.4000000000000003e-07
# 4.4e-07
# 7.280000000000001e-07
# 1.12e-06
# 1.6320000000000002e-06
# 2.2799999999999993e-06
# 3.08e-06
# 4.047999999999999e-06
# 5.2e-06
# 6.551999999999999e-06
# 8.12e-06
# 9.919999999999998e-06
# 1.1968e-05
# 1.4280000000000002e-05
# 1.6871999999999997e-05
# 1.976e-05
# 2.2960000000000004e-05
# 2.6488000000000008e-05
# 3.0359999999999997e-05
# 3.4592000000000004e-05
# 3.9200000000000004e-05
# 4.420000000000001e-05
# 4.9608e-05
# 5.544e-05
# 6.171200000000001e-05
# 6.844000000000002e-05
# 7.564e-05
# 8.332800000000001e-05
# 9.152000000000002e-05
# 0.00010023200000000003
# 0.00010948000000000003
# 0.00011928000000000004
# 0.00012964799999999998
# 0.00014059999999999998
# 0.000152152
# 0.00016432
# 0.00017712
# 0.00019056800000000004
# 0.00020468000000000005
# 0.00021947199999999996
# 0.00023496
# 0.00025116
# 0.00026808800000000004
# 0.00028576000000000003
# 0.00030419200000000006
# 0.00032340000000000005
# 0.00034340000000000005
# 0.0003642079999999999
# 0.0003858399999999999
# 0.0004083119999999999
# 0.00043163999999999995
# 0.00045584
# 0.00048092800000000004
# 0.0005069200000000001
# 0.0005338320000000001
# 0.00056168
# 0.00059048
# 0.000620248
# 0.000651
# 0.000682752
# 0.0007155200000000001
# 0.0007493200000000002
# 0.0007841680000000002
# 0.0008200800000000003
# 0.0008570720000000003
# 0.0008951600000000003
# 0.0009343600000000004
# 0.0009746879999999998
# 0.00101616
# 0.001058792
# 0.0011026
# 0.0011476000000000001
# 0.0011938080000000002
# 0.0012412400000000002
# 0.0012899120000000003
# 0.0013398400000000003
# 0.0013910400000000003
# 0.0014435280000000003
# 0.0014973200000000003
# 0.0015524320000000003
# 0.0016088800000000002
# 0.0016666800000000002
# 0.0017258479999999994
# 0.0017863999999999994
# 0.0018483519999999995
# 0.0019117199999999996
# 0.00197652
# 0.002042768
# 0.00211048
# 0.002179672
# 0.0022503600000000003
# 0.0023225600000000004
# 0.0023962880000000003
# 0.0024715600000000002
# 0.0025483920000000005
# 0.0026268000000000003
# 0.0027068000000000005
# 0.0027884080000000005
# 0.0028716399999999995
# 0.0029565119999999997
# 0.00304304
# 2.348253432000002
# 2.355610880000002
# 2.3629836800000024
# 2.3703718480000022
# 2.377775400000002
# 2.3851943520000023
# 2.3926287200000025
# 2.4000785200000023
# 2.4075437680000022
# 2.4150244800000022
# 2.4225206720000023
# 2.4300323600000024
# 2.4375595600000026
# 2.445102288000003
# 2.4526605600000027
# 2.4602343920000025
# 2.4678238000000023
# 2.475428800000002
# 2.483049408000002
# 2.490685640000002
# 2.4983375120000018
# 2.5060050400000016
# 2.513688240000002
# 2.521387128000002
# 2.529101720000002
# 2.536832032000002
# 2.544578080000002
# 2.552339880000002
# 2.560117448000002
# 2.567910800000002
# 2.5757199520000023
# 2.5835449200000022
# 2.591385720000002
# 2.5992423680000023
# 2.6071148800000024
# 2.6150032720000023
# 2.6229075600000025
# 2.6308277600000025
# 2.6387638880000024
# 2.6467159600000025
# 2.6546839920000025
# 2.6626680000000027
# 2.6706680000000027

# %% [markdown]
# Bài 3

# %%
from sympy import *

# %%
Rational(1,2) + Rational(1,3)
# Out:
# 5/6

# %%
Rational(1,2) + 1
# Out:
# 3/2

# %% [markdown]
# Bài 4

# %%
from sympy import  *
x = symbols ('x')
y = symbols ('y')

# %%
2*x + 3
# Out:
# 2*x + 3

# %%
x+2
# Out:
# x + 2

# %% [markdown]
# Bài 5a

# %%
from sympy.solvers.solvers import denoms
eq = (1/x)*1/(x-3)
dd = denoms(eq)
print(dd)
# Out:
# {x - 3, x}

# %% [markdown]
# Bài 5b

# %%
eq =(1+1/x)/(x-1)
from sympy.solvers.solvers import denoms
loai_tru = set()
for d in denoms(eq):
  for s in solve(d):
    loai_tru.add(s)
    print(loai_tru)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-512040fd8fb8> in <module>()
# ----> 1 eq =(1+1/x)/(x-1)
#       2 from sympy.solvers.solvers import denoms
#       3 loai_tru = set()
#       4 for d in denoms(eq):
#       5   for s in solve(d):
#
# NameError: name 'x' is not defined

# %% [markdown]
# Bài 10a

# %%
from sympy import Limit, Symbol
x = Symbol ('x')
Limit (1/x,x,0,dir='-').doit()
# Out:
# -oo

# %% [markdown]
# **CHƯƠNG 2 **

# %% [markdown]
# Bài 1

# %%
chuoitinhtoan ="a*b+c"
a = 2
b = 5
c = 7
eval(chuoitinhtoan)
# Out:
# 17

# %% [markdown]
# Bài 2

# %%
import sympy
x = symbols ('x')
y = symbols ('y')
bieuthuc = x+y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c8bebae53f93> in <module>()
#       1 import sympy
# ----> 2 x = symbols ('x')
#       3 y = symbols ('y')
#       4 bieuthuc = x+y
#
# NameError: name 'symbols' is not defined

# %%
thaytheso=bieuthuc.subs({x:10,y:5})
thaytheso
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3992d12eb570> in <module>()
# ----> 1 thaytheso=bieuthuc.subs({x:10,y:5})
#       2 thaytheso
#
# NameError: name 'bieuthuc' is not defined

# %%
bieuthuc_theo_uv=bieuthuc.subs({x:u,y:v})
bieuthuc_theo_uv

# %%
thaythe_tinhtoan = bieuthuc.subs({x:2*u*v,y:u**2+v**2})
thaythe_tinhtoan

# %%
import sympy
x = symbols ('x')
y = symbols ('y')
bieuthuc=x+y
bieuthuc2=x**2+y**2
u = symbols ('u')
v = symbols ('v')
a = symbols ('a')

# %%
from sympy import sin, cos
bieuthuc_theo_uv=bieuthuc2.subs({x:a*sin(u),y:a*cos(u)})
bieuthuc_theo_uv

# %%
bieuthuc_theo_uv.simplify()

# %% [markdown]
# Bài 3

# %%
danhsach_so=[10,15,20]
danhsach_so[0]
# Out:
# 10

# %%
danhsach_so[1]
# Out:
# 15

# %%
danhsach_so[2]
# Out:
# 20

# %% [markdown]
# Bài 4

# %%
ds= [1,2,3]
for so in ds:
    print(so)
# Out:
# 1
# 2
# 3

# %%
ds =[10,11,12]
for chiso, giatri in enumerate(ds):
  print(chiso, giatri)
# Out:
# 0 10
# 1 11
# 2 12

# %% [markdown]
# Bài 5

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6fcf9dfbd479> in <module>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
x_number=[1,6,8]
y_number=[2,5,8]
from pylab import plot,show

# %%
plot(x_number,y_number)
show()

# %% [markdown]
# Bài 6

# %%
plot(x_number,y_number,marker='o')
show()

# %%
hcm_rain =[13.8,4.1,10.5,50.4,218.4,311.7,293.7,269.8,327.1,266.7,116.5,48.3]
months =range(1,13)
plot(months,hcm_rain,marker='o')
show()

# %% [markdown]
# **CHƯƠNG 3 **

# %% [markdown]
# Bài 1

# %%
def luythua(x, n):
  ketqua = 1
  for i in range(n):
    ketqua = ketqua*x
  return ketqua

# %%
luythua(2,1)
# Out:
# 2

# %%
luythua(2,0)
# Out:
# 1

# %% [markdown]
# Bài 4

# %%
while True:
  try:
    x = int(input("Vui long nhap so:"))
  except:
      print("So vua  nhap sa1")
  else:
      print('SO vua nhap la'+ str(x))
      break
  finally:
    print("Da hoan thanh chuong trinh")
# Out:
# Vui long nhap so:0
# SO vua nhap la0
# Da hoan thanh chuong trinh

# %% [markdown]
# Bài 5

# %%
def frange(batdau,ketthuc,buocnhay):
  day_ketqua=[]
  while batdau<ketthuc:
    day_ketqua.append(batdau)
    batdau= batdau + buocnhay
  return day_ketqua

# %%
tu0den2 = frange(0, 2, 0.2)
tu0den2
# Out:
# [0,
#  0.2,
#  0.4,
#  0.6000000000000001,
#  0.8,
#  1.0,
#  1.2,
#  1.4,
#  1.5999999999999999,
#  1.7999999999999998,
#  1.9999999999999998]

# %% [markdown]
# Bài 6

# %%
from matplotlib import pyplot as plt
import math

# %%
def draw_graph(x,y):
  plt.plot(x,y)
  plt.xlabel('Truc X')
  plt.ylabel('Truc Y')
  plt.title('Do thi bai toan nam bong')

# %%
def frange(start,final,interval):
  numbers = []
  while start < final:
    numbers.append(start)
    start =start + interval
  return numbers

# %%
def draw_trajectory(u,theta):
  g = 9.8
  theta = math.radians(theta)
  t_fight = 2*u*math.sin(theta)/g
  interval = frange(0, t_fight, 0.001 )
  x = []
  y = []
  for t in interval:
    x.append(u*math.cos(theta)*t)
    y.append(u*math.sin(theta)*t - 0.5*g*t*t)
  draw_graph(x.y)

# %%
3
try:
  u = float(input('Nhap van toc ban dau(m/s):'))
  theta=float(input('Nhap goc bay (degrees):'))
except ValueError:
  print("Nhap cac gia tri sai!")
else:
  draw_trajectory(u,theta)
  plt.show()
finally:
  print("Hoan thanh chuong trinh")
# Out:
# Nhap van toc ban dau(m/s):012
# Nhap goc bay (degrees):21
# Hoan thanh chuong trinh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-64bdc9c986ea> in <module>()
#       6   print("Nhap cac gia tri sai!")
#       7 else:
# ----> 8   draw_trajectory(u,theta)
#       9   plt.show()
#      10 finally:
#
# <ipython-input-31-20b1dbe175eb> in draw_trajectory(u, theta)
#       9     x.append(u*math.cos(theta)*t)
#      10     y.append(u*math.sin(theta)*t - 0.5*g*t*t)
# ---> 11   draw_graph(x.y)
#
# AttributeError: 'list' object has no attribute 'y'

# %% [markdown]
# **CHƯƠNG 4**

# %%
import numpy as np
mienchia=np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %%
import numpy as np  
import matplotlib.pyplot as plt

# %%
fs =[1,2,4]
all_time = np.linspace (0,2,200)
t=all_time[:100]

# %%
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/ThChuong4/basics_pyhon.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import numpy as np 
import matplotlib.pyplot as plt

fs = [1,2,4]
all=time = np.linspace(0,2,200)
t = all_time[:100]

fig, ax=plt.sub.plot()
for f in fs:
  y = np.sin(2*np.pi*f*t)
  ax.plot (t,y,label='{}Hz'.format(f))
plt.legend()
import os 
os.chdir('d\\'')
plt.savefig ('basics_python.pdf')
plt.show()
# Out:
#   File "<ipython-input-21-45328900d20a>", line 14
#     os.chdir('d\\'')
#                     ^
# SyntaxError: EOL while scanning string literal

# %%
def thue(phan_tram):return lambda x: x * phan_tram
hcm=thue(0.012)
hn=thue(0.001)
hcm(10000000)
hn(10000000)
# Out:
# 10000.0

# %%
hinhthang = lambda f,a,b: (b-a) * (f(a) + f(b))/2
from math import exp
hinhthang(exp,0,1)
# Out:
# 1.8591409142295225

# %%
"""
Ham tinh theo luat hinh thang
cho ham(x) tu [trai,phai]
"""
def traprule(ham,trai,phai):
  return (phai-trai)*(ham(trai)+ham(phai))/2

import math
S= "Bieu thuc can tinh tich phan la e^x:"
print(S+'[a,b]')
A=float(input('Nhap a:'))
B=float(input)

# %% [markdown]
# **CHƯƠNG 5 **

# %% [markdown]
# Bài 1

# %%
x = 3 
print (x)
# Out:
# 3

# %%
import math
x = math.sqrt(x+1)
print(x)
# Out:
# 2.0

# %%
x = math.sqrt(1+x)
print (x)
# Out:
# 1.7320508075688772

# %%
x = math.sqrt(1+x)
print (x)
# Out:
# 1.6528916502810695

# %% [markdown]
# Bài 2

# %%
import math
x = 3
lap = 1
while (x != math.sqrt(x+1)):
 x = math.sqrt(x+1)
 lap = lap +1

# %%
x
# Out:
# 1.6528916502810695

# %% [markdown]
# Bài 3

# %%
import sympy as sp
from sympy import Symbol
x = Symbol('x')
sp.solve(x-sp.sqrt(1+x),x)
# Out:
# [1/2 + sqrt(5)/2]

# %% [markdown]
# Bài 4

# %%
import numpy as np
v1 = np.array([1., 2., 3.]) # tạo vector 3 chiều
v2 = np.array([2., 1., 0.])
v3 = v1 + v2 # cộng vector
v3
# Out:
# array([3., 3., 3.])

# %%
3*v1 + 2*v2
# Out:
# array([7., 8., 9.])

# %%
[1, 2, 3] + [2, 1, 0]
# Out:
# [1, 2, 3, 2, 1, 0]

# %%
3*[1, 2, 3] + 2*[2, 1, 0]
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 2, 1, 0, 2, 1, 0]

# %%
v4 = np.hstack([v1, v2])
np.dot(v1, v2)
# Out:
# 4.0

# %%
angles = np.linspace(0, np.pi/2, 5)
angles
# Out:
# array([0.        , 0.39269908, 0.78539816, 1.17809725, 1.57079633])

# %%
np.sin(angles)
# Out:
# array([0.        , 0.38268343, 0.70710678, 0.92387953, 1.        ])

# %% [markdown]
# Bài 5

# %%
import numpy as np
goc = np.pi/3
A = np.array([ [np.cos(goc), -np.sin(goc)],[np.sin(goc), np.cos(goc)] ])
V = np.array([1. , 0. ])
Y = np.dot(A, V)
Y
# Out:
# array([0.5      , 0.8660254])

# %% [markdown]
# Bài 6

# %%
from numpy import diff
dx = 0.1
y = [1, 2, 3, 4, 4, 5, 6]
dy = diff(y)/dx
dy
# Out:
# array([10., 10., 10.,  0., 10., 10.])

# %%
z = np.array([1, 2, 3, 4, 4, 5, 6])
dz = diff(z)/dx
dz
# Out:
# array([10., 10., 10.,  0., 10., 10.])

# %%
from numpy import diff
x = [.1, .2, .5, .6, .7, .8, .9]
y = [1, 2, 3, 4, 4, 5, 6]
dydx = diff(y)/diff(x)
print (dydx)
# Out:
# [10.          3.33333333 10.          0.         10.         10.        ]

# %% [markdown]
# Bài 7

# %%
from sympy.geometry import *

# %%
# Tạo các điểm P1, P2, P3 và P4
P1 = Point(0, 0)
P2 = Point(3, 4)
P3 = Point(2, -1)
P4 = Point(-1, 5)

# %%
# Tạo 2 đoạn đường S1 và S2:
S1 = Segment(P1, P2)
S2 = Segment(P3, P4)

# %%
# Kiểm 3 điểm thẳng hàng: 
Point.is_collinear(P1, P2, P3)
# Out:
# False

# %%
# Độ dài của đoạn đường S1 
S1.length
# Out:
# 5

# %%
# Lấy trung điểm của đoạn 2: 
S2.midpoint
# Out:
# Point2D(1/2, 2)

# %%
# Tính độ dốc của đường S1
S1.slope
# Out:
# 4/3

# %%
# Tìm vị trí giao nhau giữa hai đoạn đường
S1.intersection(S2)
# Out:
# [Point2D(9/10, 6/5)]

# %%
# Góc giữa hai đoạn đường 
Segment.angle_between(S1, S2)
# Out:
# acos(sqrt(5)/5)

# %%
# Kiểm đoạn đường S1 có chứa điểm P3 hay không?
S1.contains(P3)
# Out:
# False

# %%
# Lập và xem phương trình đường thẳng L1 đi qua 2 điểm P1 và P2:
L1 = Line(P1, P2)
L1.equation()
# Out:
# -4*x + 3*y

# %%
# Kiểm tính song song:
L1.is_parallel(S1)
# Out:
# True

# %%
L1.is_parallel(S2)
# Out:
# False

# %% [markdown]
# Bài 8

# %%
import sympy

# %%
from sympy import *
x = Symbol('x')
f = x * sin(1/x)
c = Symbol('c')
delta = Symbol('delta')
c = 0
delta = 1/4
sympy.plot(f,(x, c - delta, c + delta))
sympy.plot(f, abs(x), -abs(x),(x, c-delta, c + delta))

# %% [markdown]
# Bài 9

# %%
from sympy import Symbol, solve, Derivative
x = Symbol('x')
f = -x**2+4*x-3
d1=Derivative(f, x).doit()
cuctri = solve(d1)
cuctri
# Out:
# [2]

# %%
A = cuctri[0]
d2 = Derivative(d1, x).doit()
d2.subs({x:A}).evalf()
# Out:
# -2.00000000000000

# %%
x_min=0
x_max=4
f.subs({x:A}).evalf()
# Out:
# 1.00000000000000

# %%
f.subs({x:A}).evalf()

# %%
f.subs({x:x_min}).evalf()
# Out:
# -3.00000000000000

# %%
f.subs({x:x_max}).evalf()
# Out:
# -3.00000000000000

# %% [markdown]
# **CHƯƠNG 6 **

# %% [markdown]
# Bài 1

# %%
import math
def giaithua(n):
  if (n==0):
    return 1
  else:
    return n*giaithua(n-1) 
giaithua(3)
# Out:
# 6

# %%
giaithua(4)
# Out:
# 24

# %% [markdown]
# Bài 2

# %%
def fibo(n):
 if n == 0:
    return 0
 if n == 1:
    return 1
 return fibo(n-1) + fibo(n-2)

# %%
fibo(4)
# Out:
# 3

# %%
fibo(5)
# Out:
# 5

# %%
fibo(6)
# Out:
# 8

# %% [markdown]
# Bài 3

# %%
def an_exp_an(n):
  if n == 1:
    return 1.0/2
  else:
    return an_exp_an(n-1)**an_exp_an(n-1)

# %%
an_exp_an(1)
# Out:
# 0.5

# %%
an_exp_an(2)
# Out:
# 0.7071067811865476

# %%
an_exp_an(3)
# Out:
# 0.7826540273556803

# %%
an_exp_an(4)
# Out:
# 0.8254713306050621

# %%
an_exp_an(20)
# Out:
# 0.9554829674842079

# %%
def bai4(n):
 if n==1:
  return 4
 else:
  return 5.0/(6-bai4(n-1))

# %%
bai4(5)
# Out:
# 1.019108280254777

# %% [markdown]
# Bài 5

# %%
def tisoFibo(n):
 if n==1:
  return 1
 else:
  return 1.0 + 1.0/tisoFibo(n-1)

# %%
for i in range(1, 11):
    print (i, tisoFibo(i))
# Out:
# 1 1
# 2 2.0
# 3 1.5
# 4 1.6666666666666665
# 5 1.6
# 6 1.625
# 7 1.6153846153846154
# 8 1.619047619047619
# 9 1.6176470588235294
# 10 1.6181818181818182

# %% [markdown]
# **CHƯƠNG 7 **

# %% [markdown]
# Bài 1

# %%
from sympy import Symbol, Integral
x = Symbol('x')
f = 1.0/x
unbound1 = Integral(f, (x, 0, 2))
unbound1.doit()
# Out:
# oo

# %% [markdown]
# Bài 2

# %%
from sympy import Symbol, Integral
x = Symbol('x')
f = 1.0/x**2
unbound2 = Integral(f, (x, -1, 1)) 
unbound2.doit()
# Out:
# oo

# %% [markdown]
# Bài 3

# %%
from sympy import Symbol, Integral, Abs
x = Symbol('x')
f = Abs(x)
discontinous1 = Integral(f, (x, -1, 2))
discontinous1.doit()
# Out:
# 5/2

# %% [markdown]
# Bài 4

# %%
from sympy import Symbol, Integral
x = Symbol('x')
f = x**(0.5)
undef1 = Integral(f, (x, -1, 1))
undef1.doit()
# Out:
# 0.666666666666667 + 0.666666666666667*I

# %% [markdown]
# Bài 5

# %%
from scipy import integrate
import numpy as np
y = np.array([0.0, 4.1, 8.9, 8.5, 6.7, 4.3, 2.5, 1.2,0.2])
x = np.arange(0,9)
integrate.simps(y, x)
# Out:
# 36.26666666666666

# %% [markdown]
# **CHƯƠNG 8**

# %% [markdown]
# Bài 2

# %%
from sympy import solve, sin
x = Symbol('x')
y = Symbol('y')

# %%
solve(x-1,x)
# Out:
# [1]

# %%
solve(x**2-1,x)
# Out:
# [-1, 1]

# %%
solve(x**2+1,x)
# Out:
# [-I, I]

# %%
solve(sin(x),x)
# Out:
# [0, pi]

# %% [markdown]
# Bài 3

# %%
from sympy import solveset
solveset(sin(x),x)
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + pi), Integers), ImageSet(Lambda(_n, 2*_n*pi), Integers))

# %% [markdown]
# Bài 4

# %%
from sympy import solveset, S
from sympy.abc import x, y, z

# %%
solveset(x**2 + 1, x) # mac dinh la mien so phuc: domain = S.Complexes
# Out:
# FiniteSet(I, -I)

# %%
solveset(x**2 + 1, x, domain = S.Reals) # mien so thuc
# Out:
# EmptySet

# %% [markdown]
# Bài  6

# %%
solveset((sin(x)+x)*(x**2-9), x, domain = S.Reals)
# Out:
# Union(ConditionSet(x, Eq(x + sin(x), 0), Reals), FiniteSet(-3, 3))

# %% [markdown]
# Bài 7

# %%
from sympy import exp, S

# %%
solveset(exp(x) > 1, x, domain = S.Reals)
# Out:
# Interval.open(0, oo)

# %%
solveset(E**x > 1, x, domain = S.Reals)
# Out:
# Interval.open(0, oo)

# %%
R = S.Reals

# %%
solveset(E**x > E, x, R)
# Out:
# Interval.open(1, oo)

# %% [markdown]
# Bài 8

# %%
from sympy import Derivative, Symbol, solve
x = Symbol('x')
y = Symbol('y')
z = Symbol('z')
f = 4*x*y - 8*x - 5 + z*(x+y-50) 
dx = Derivative(f, x).doit()
dy = Derivative(f, y).doit()
dz = Derivative(f, z).doit()

# %%
nghiem = solve([dx, dy, dz], (x,y,z))
print (nghiem)
# Out:
# {x: 24, y: 26, z: -96}

# %%
xx = nghiem[x]
yy = nghiem[y]
4*xx*yy - 8*xx – 5
# Out:
#   File "<ipython-input-78-ff3c12cfc4c3>", line 3
#     4*xx*yy - 8*xx – 5
#                    ^
# SyntaxError: invalid character in identifier
